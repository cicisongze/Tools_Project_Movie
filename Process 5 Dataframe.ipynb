# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

# %%
def money(year):
    list_=list()
    for page in range(1,31):
        url='https://www.themoviedb.org/discover/movie?language=en&list_style=1&media_type=movie&page='+str(page)+'&primary_release_year=%s&sort_by=popularity.desc&vote_count.gte=0'%year
        response = requests.get(url)
    
        #check validity of website
        if response.status_code != 200:
            print("Wrong page!")
        else:
            results_page = BeautifulSoup(response.content,'lxml')
            sectors=results_page.find_all('div',{"class":'flex'})
            for sector in sectors:
                movie_link='https://www.themoviedb.org'+sector.find('a').get('href')
                #print(movie_link)
        
                newresponse=requests.get(movie_link)
                if newresponse.status_code != 200:
                    print("Wrong page!")
                else:
                    dict_=dict()
                    results_page = BeautifulSoup(newresponse.content,'lxml')
                    movie_name=results_page.find('h2').get_text()
                    info=results_page.find('section',{"class":'facts left_column'})
                    language=info.find_all('p')[3].get_text()
                    runtime=info.find_all('p')[4].get_text()
                    budget=info.find_all('p')[5].get_text()
                    revenue=info.find_all('p')[6].get_text()
                    date=results_page.find('ul',{"class":'releases'}).get_text()
                    pattern=r'\w+\s+\d+,\s\d+'
                    string=date
                    match = re.search(pattern, string)
                    release_date=match.group()
                    
                    list_.append((movie_name,language,runtime,budget,revenue,release_date))
    return list_

# %%
# print(len(money(2012)))
list_2012=money(2012)

name_2012=[]
for i in range(len(list_2012)):
    name_2012.append(list_2012[i][0])
name_2012

language_2012=list()
lang_2012_re=list()
for i in range(len(list_2012)):
    language_2012.append(list_2012[i][1])

for j in language_2012:
    pattern=r' \w+$'
    match = re.findall(pattern, j)
    lang_2012_re.append(match)

runtime_2012=list()
runtime_2012_re=list()
for i in range(len(list_2012)):
    runtime_2012.append(list_2012[i][2])

for j in runtime_2012:
    pattern=r'\w+ \w+m$'
    match = re.findall(pattern, j)
    runtime_2012_re.append(match)

budget_2012=list()
budget_2012_re=list()
for i in range(len(list_2012)):
    budget_2012.append(list_2012[i][3])

for j in budget_2012:
    pattern=r'[$][0-9,.]+'
    match = re.findall(pattern, j)
    budget_2012_re.append(match)

revenue_2012=list()
revenue_2012_re=list()
for i in range(len(list_2012)):
    revenue_2012.append(list_2012[i][4])

for j in revenue_2012:
    pattern=r'[$][0-9,.]+'
    match = re.findall(pattern, j)
    revenue_2012_re.append(match)
    
releasedate_2012=list()
for i in range(len(list_2012)):
    releasedate_2012.append(list_2012[i][5])
    
dic_2012={'Movie':name_2012,
          'Release_date':releasedate_2012,
       'Language':lang_2012_re,
       'Runtime':runtime_2012_re,
       'Budget':budget_2012_re,
       'Revenue':revenue_2012_re}

df2012=pd.DataFrame.from_dict(dic_2012)
df2012
# Out:
#                                                  Movie        Release_date  \
# 0                                         The Avengers        May  4, 2012
# 1                                         The Avengers        May  4, 2012
# 2                                The Dark Knight Rises       July 20, 2012
# 3                                     Django Unchained   December 11, 2012
# 4                                                Brave       June 22, 2012
# 5                                       Wreck-It Ralph   November  2, 2012
# 6                          Snow White and the Huntsman       June  1, 2012
# 7                                            The Lorax      March  1, 2012
# 8                    The Hobbit: An Unexpected Journey   December 14, 2012
# 9                                        Mirror Mirror      March 30, 2012
# 10                                             Skyfall   November  9, 2012
# 11           The Twilight Saga: Breaking Dawn - Part 2   November 16, 2012
# 12                              The Amazing Spider-Man       July  4, 2012
# 13                Sexual Chronicles of a French Family       June  1, 2012
# 14                                  Hotel Transylvania  September 28, 2012
# 15                                    The Hunger Games      March 23, 2012
# 16                                          Prometheus       June  8, 2012
# 17                                      21 Jump Street      March 12, 2012
# 18                          Silent Hill: Revelation 3D    October 26, 2012
# 19                  Madagascar 3: Europe's Most Wanted       June  8, 2012
# 20                          Ice Age: Continental Drift       July 13, 2012
# 21                                    American Reunion      April  6, 2012
# 22                                    American Reunion      April  6, 2012
# 23                              The Cabin in the Woods      March  9, 2012
# 24                            Wrong Turn 5: Bloodlines    October 23, 2012
# 25                               Rise of the Guardians   November 21, 2012
# 26                                     Christmas Crush   November 17, 2012
# 27                     The Perks of Being a Wallflower  September 21, 2012
# 28                           Tutto tutto niente niente   November 30, 2012
# 29                                   The Bourne Legacy     August 10, 2012
# ..                                                 ...                 ...
# 600                                       Piranhaconda       June 16, 2012
# 601                                         Good Deeds   February 23, 2012
# 602                                           Comedown     August 23, 2012
# 603                                        Ustad Hotel       June 29, 2012
# 604  Puella Magi Madoka Magica the Movie Part II: E...    October 19, 2012
# 605                   Cheerful Weather for the Wedding   December  7, 2012
# 606                                    Fresh Guacamole      March  2, 2012
# 607                                      In Their Skin      April 21, 2012
# 608                      Rape Zombie: Lust of the Dead  September 10, 2013
# 609                         Ben 10: Destroy All Aliens      March 23, 2012
# 610                         Ben 10: Destroy All Aliens      March 23, 2012
# 611                                 Ek Main Aur Ekk Tu   February 10, 2012
# 612                                      The Assassins  September 26, 2012
# 613                                       Spike Island    October 13, 2013
# 614                                     Helter Skelter       July 14, 2012
# 615                              Hello I Must Be Going  September  7, 2012
# 616                                      The Guardians    October 10, 2012
# 617                                              Shell   November 26, 2012
# 618                                             Eungyo      April 25, 2012
# 619  Bronies: The Extremely Unexpected Adult Fans o...   November  4, 2012
# 620                                            Bowling       July 18, 2012
# 621                                        The Lookout  September  9, 2012
# 622                                            Howling   February 16, 2012
# 623                                  The Invisible War    January 20, 2012
# 624                                 Grimm's Snow White      March 13, 2012
# 625                              The Stroller Strategy   November 11, 2012
# 626  London 2012 Olympic Opening Ceremony: Isles of...       July 27, 2012
# 627                              Undercover Bridesmaid      April 15, 2012
# 628                Saints and Soldiers: Airborne Creed     August 17, 2012
# 629                               Blue and Not So Pink   November 27, 2012
#
#        Language               Runtime             Budget              Revenue
# 0    [ English]              [2h 23m]  [$220,000,000.00]  [$1,519,557,910.00]
# 1    [ English]              [2h 23m]  [$220,000,000.00]  [$1,519,557,910.00]
# 2    [ English]              [2h 45m]  [$250,000,000.00]  [$1,084,939,099.00]
# 3            []                    []                 []    [$100,000,000.00]
# 4    [ English]              [1h 33m]  [$185,000,000.00]    [$538,983,207.00]
# 5    [ English]              [1h 48m]  [$165,000,000.00]    [$471,222,889.00]
# 6    [ English]               [2h 7m]  [$170,000,000.00]    [$396,600,000.00]
# 7    [ English]              [1h 26m]   [$70,000,000.00]    [$348,840,316.00]
# 8    [ English]              [2h 49m]  [$250,000,000.00]  [$1,021,103,568.00]
# 9    [ English]              [1h 46m]   [$85,000,000.00]    [$183,018,522.00]
# 10   [ English]              [2h 23m]  [$200,000,000.00]  [$1,108,561,013.00]
# 11   [ English]              [1h 55m]  [$120,000,000.00]    [$829,000,000.00]
# 12   [ English]              [2h 16m]  [$215,000,000.00]    [$752,215,857.00]
# 13           []                    []                 []                   []
# 14   [ English]              [1h 31m]   [$85,000,000.00]    [$358,375,603.00]
# 15   [ English]              [2h 22m]   [$75,000,000.00]    [$691,210,692.00]
# 16   [ English]               [2h 4m]  [$130,000,000.00]    [$403,170,142.00]
# 17   [ English]              [1h 49m]   [$42,000,000.00]    [$201,585,328.00]
# 18   [ English]              [1h 34m]   [$20,000,000.00]     [$52,302,796.00]
# 19   [ English]              [1h 33m]  [$145,000,000.00]    [$746,921,274.00]
# 20   [ English]              [1h 28m]   [$95,000,000.00]    [$877,244,782.00]
# 21   [ English]              [1h 53m]   [$50,000,000.00]    [$234,989,584.00]
# 22   [ English]              [1h 53m]   [$50,000,000.00]    [$234,989,584.00]
# 23           []                    []                 []     [$30,000,000.00]
# 24   [ English]              [1h 31m]                 []                   []
# 25   [ English]              [1h 37m]  [$145,000,000.00]    [$306,941,670.00]
# 26   [ English]              [1h 28m]                 []                   []
# 27   [ English]              [1h 43m]   [$13,000,000.00]     [$33,400,000.00]
# 28   [ Italian]                    []    [$5,579,750.00]      [$8,927,600.00]
# 29   [ English]              [2h 15m]  [$130,000,000.00]    [$276,572,938.00]
# ..          ...                   ...                ...                  ...
# 600  [ English]              [1h 30m]    [$1,000,000.00]                   []
# 601  [ English]              [1h 51m]                 []                   []
# 602  [ English]              [1h 30m]                 []                   []
# 603          []  [Language Malayalam]                 []                   []
# 604          []                    []                 []                   []
# 605  [ English]              [1h 33m]                 []                   []
# 606  [ English]               [0h 2m]                 []                   []
# 607          []                    []                 []      [$4,000,000.00]
# 608          []                    []                 []                   []
# 609  [ English]               [1h 6m]                 []                   []
# 610  [ English]               [1h 6m]                 []                   []
# 611          []                    []                 []                   []
# 612          []                    []                 []                   []
# 613  [ English]              [1h 36m]                 []                   []
# 614          []                    []                 []                   []
# 615  [ English]              [1h 35m]                 []                   []
# 616          []                    []                 []                   []
# 617  [ English]              [1h 30m]                 []                   []
# 618          []                    []                 []                   []
# 619  [ English]              [1h 28m]      [$348,164.00]                   []
# 620   [ French]              [1h 30m]                 []                   []
# 621          []                    []                 []                   []
# 622          []                    []                 []                   []
# 623  [ English]              [1h 33m]                 []                   []
# 624  [ English]              [1h 29m]                 []                   []
# 625          []                    []                 []                   []
# 626  [ English]              [3h 40m]                 []                   []
# 627  [ English]              [1h 32m]                 []                   []
# 628  [ English]              [1h 34m]                 []                   []
# 629          []                    []                 []                   []
#
# [630 rows x 6 columns]

# %%
list_2013=money(2013)

name_2013=[]
for i in range(len(list_2013)):
    name_2013.append(list_2013[i][0])
name_2013

language_2013=list()
lang_2013_re=list()
for i in range(len(list_2013)):
    language_2013.append(list_2013[i][1])

for j in language_2013:
    pattern=r' \w+$'
    match = re.findall(pattern, j)
    lang_2013_re.append(match)

runtime_2013=list()
runtime_2013_re=list()
for i in range(len(list_2013)):
    runtime_2013.append(list_2013[i][2])

for j in runtime_2013:
    pattern=r'\w+ \w+m$'
    match = re.findall(pattern, j)
    runtime_2013_re.append(match)

budget_2013=list()
budget_2013_re=list()
for i in range(len(list_2013)):
    budget_2013.append(list_2013[i][3])

for j in budget_2013:
    pattern=r'[$][0-9,.]+'
    match = re.findall(pattern, j)
    budget_2013_re.append(match)

revenue_2013=list()
revenue_2013_re=list()
for i in range(len(list_2013)):
    revenue_2013.append(list_2013[i][4])

for j in revenue_2013:
    pattern=r'[$][0-9,.]+'
    match = re.findall(pattern, j)
    revenue_2013_re.append(match)
    
releasedate_2013=list()
for i in range(len(list_2013)):
    releasedate_2013.append(list_2013[i][5])
    
dic_2013={'Movie':name_2013,
          'Release_date':releasedate_2013,
       'Language':lang_2013_re,
       'Runtime':runtime_2013_re,
       'Budget':budget_2013_re,
       'Revenue':revenue_2013_re}

df2013=pd.DataFrame.from_dict(dic_2013)
df2013
# Out:
#                                                  Movie        Release_date  \
# 0                                 Thor: The Dark World   November  8, 2013
# 1                                 Thor: The Dark World   November  8, 2013
# 2                                               Frozen   November 19, 2013
# 3                                         Man of Steel       June 14, 2013
# 4                                      Despicable Me 2       July  3, 2013
# 5                                            The Purge       June  6, 2013
# 6                                           Iron Man 3        May  3, 2013
# 7                      The Hunger Games: Catching Fire   November 22, 2013
# 8                                                Enemy      March 14, 2014
# 9                                       Now You See Me        May 31, 2013
# 10                                    12 Years a Slave    October 30, 2013
# 11                 The Hobbit: The Desolation of Smaug   December 13, 2013
# 12                             The Wolf of Wall Street   December 17, 2013
# 13                                            Oblivion      April 18, 2013
# 14                                             Gravity     August 31, 2013
# 15                                                Epic        May 24, 2013
# 16                                Nymphomaniac: Vol. I      March  6, 2014
# 17                                       The Conjuring       July 19, 2013
# 18                                 Monsters University       June 21, 2013
# 19                                               Horns    October  3, 2014
# 20                                          Kick-Ass 2     August 16, 2013
# 21                                             Elysium     August  9, 2013
# 22                                             Elysium     August  9, 2013
# 23                               The Hangover Part III        May 23, 2013
# 24                                         World War Z       June 21, 2013
# 25                                      The Love Punch  September 12, 2013
# 26                                              Stoker    January 20, 2013
# 27                             Star Trek Into Darkness        May 16, 2013
# 28                      Hansel & Gretel: Witch Hunters    January 25, 2013
# 29                                    The Great Gatsby        May 10, 2013
# ..                                                 ...                 ...
# 600                                    Shield of Straw      April 25, 2013
# 601                                   See You Tomorrow      April 20, 2013
# 602                                       Autumn Blood  September 10, 2013
# 603                     A Birder's Guide to Everything      April 21, 2013
# 604                                Saving General Yang      April  4, 2013
# 605                                      500 MPH Storm   February 28, 2013
# 606                    Legends of Oz: Dorothy's Return        May  9, 2014
# 607  Puella Magi Madoka Magica the Movie Part III: ...   December  3, 2013
# 608                                 Breaking the Girls       July 26, 2013
# 609                                       Zombie Night    October  8, 2013
# 610                                       Zombie Night    October  8, 2013
# 611                                       Rigor Mortis  September  6, 2013
# 612                                    Cottage Country   November  1, 2013
# 613                                         Dirty Wars    January 18, 2013
# 614                                      Goodbye World       June 15, 2013
# 615                                   Pleasure or Pain    October 22, 2013
# 616                                 Inequality for All    January 19, 2013
# 617                                       Eastern Boys      April  2, 2013
# 618                                        Go Goa Gone        May 10, 2013
# 619                                               Somm   November  7, 2012
# 620                                  Hateship Loveship      April 11, 2014
# 621                                       Touchy Feely    January 19, 2013
# 622             The Strange Color of Your Body's Tears     August 12, 2013
# 623                                     Life of a King       June 22, 2013
# 624                                       Blue Caprice  September 13, 2013
# 625   A Certain Magical Index: The Miracle of Endymion   February 23, 2013
# 626                                            Goddess      March 12, 2013
# 627                                 Pee Mak Phrakanong      March 28, 2013
# 628                                   The Big Bad Wolf       July 10, 2013
# 629                                      The Wolverine       July 25, 2013
#
#        Language   Runtime             Budget              Revenue
# 0    [ English]  [1h 52m]  [$170,000,000.00]    [$644,571,402.00]
# 1    [ English]  [1h 52m]  [$170,000,000.00]    [$644,571,402.00]
# 2            []        []                 []    [$150,000,000.00]
# 3    [ English]  [2h 23m]  [$225,000,000.00]    [$668,045,518.00]
# 4    [ English]  [1h 38m]   [$76,000,000.00]    [$970,761,885.00]
# 5    [ English]  [1h 26m]    [$3,000,000.00]     [$89,328,627.00]
# 6    [ English]  [2h 10m]  [$200,000,000.00]  [$1,215,439,994.00]
# 7    [ English]  [2h 26m]  [$130,000,000.00]    [$847,423,452.00]
# 8    [ English]  [1h 31m]                 []      [$3,396,726.00]
# 9    [ English]  [1h 56m]   [$75,000,000.00]    [$117,698,894.00]
# 10   [ English]  [2h 14m]   [$20,000,000.00]    [$187,000,000.00]
# 11   [ English]  [2h 41m]  [$250,000,000.00]    [$958,400,000.00]
# 12           []        []                 []    [$100,000,000.00]
# 13   [ English]   [2h 4m]  [$120,000,000.00]    [$286,168,572.00]
# 14           []        []                 []                   []
# 15   [ English]  [1h 42m]  [$100,000,000.00]    [$268,426,634.00]
# 16   [ English]  [1h 58m]                 []     [$10,285,896.00]
# 17   [ English]  [1h 52m]   [$13,000,000.00]    [$319,494,638.00]
# 18   [ English]  [1h 44m]  [$200,000,000.00]    [$743,559,607.00]
# 19   [ English]   [2h 0m]                 []                   []
# 20   [ English]  [1h 43m]   [$28,000,000.00]     [$60,700,000.00]
# 21   [ English]  [1h 49m]  [$115,000,000.00]    [$286,140,700.00]
# 22   [ English]  [1h 49m]  [$115,000,000.00]    [$286,140,700.00]
# 23   [ English]  [1h 40m]  [$103,000,000.00]    [$362,000,072.00]
# 24   [ English]  [1h 56m]  [$200,000,000.00]    [$531,865,000.00]
# 25   [ English]  [1h 34m]                 []                   []
# 26           []        []                 []     [$12,000,000.00]
# 27   [ English]  [2h 12m]  [$190,000,000.00]    [$467,365,246.00]
# 28   [ English]  [1h 28m]   [$50,000,000.00]    [$224,803,475.00]
# 29   [ English]  [2h 23m]  [$105,000,000.00]    [$351,040,419.00]
# ..          ...       ...                ...                  ...
# 600          []        []                 []                   []
# 601          []        []                 []                   []
# 602  [ English]  [1h 40m]                 []                   []
# 603  [ English]  [1h 26m]                 []                   []
# 604          []        []                 []     [$20,000,000.00]
# 605  [ English]  [1h 30m]    [$3,000,000.00]                   []
# 606  [ English]  [1h 28m]   [$70,000,000.00]     [$18,662,027.00]
# 607          []        []                 []                   []
# 608  [ English]  [1h 23m]                 []                   []
# 609  [ English]  [1h 28m]    [$1,000,000.00]                   []
# 610  [ English]  [1h 28m]    [$1,000,000.00]                   []
# 611          []        []                 []                   []
# 612  [ English]  [1h 31m]                 []                   []
# 613  [ English]  [1h 27m]                 []                   []
# 614  [ English]  [1h 41m]                 []                   []
# 615  [ English]  [1h 42m]                 []                   []
# 616  [ English]  [1h 28m]                 []                   []
# 617   [ French]   [2h 8m]                 []                   []
# 618          []        []                 []                   []
# 619          []        []                 []                   []
# 620  [ English]  [1h 43m]                 []                   []
# 621  [ English]  [1h 29m]                 []         [$35,022.00]
# 622          []        []                 []                   []
# 623  [ English]  [1h 41m]                 []                   []
# 624  [ English]  [1h 33m]                 []                   []
# 625          []        []                 []                   []
# 626  [ English]  [1h 45m]          [$114.00]                   []
# 627          []        []                 []                   []
# 628          []        []                 []                   []
# 629  [ English]   [2h 6m]  [$120,000,000.00]    [$415,440,673.00]
#
# [630 rows x 6 columns]

# %%
list_2014=money(2014)

name_2014=[]
for i in range(len(list_2014)):
    name_2014.append(list_2014[i][0])
name_2014

language_2014=list()
lang_2014_re=list()
for i in range(len(list_2014)):
    language_2014.append(list_2014[i][1])

for j in language_2014:
    pattern=r' \w+$'
    match = re.findall(pattern, j)
    lang_2014_re.append(match)

runtime_2014=list()
runtime_2014_re=list()
for i in range(len(list_2014)):
    runtime_2014.append(list_2014[i][2])

for j in runtime_2014:
    pattern=r'\w+ \w+m$'
    match = re.findall(pattern, j)
    runtime_2014_re.append(match)

budget_2014=list()
budget_2014_re=list()
for i in range(len(list_2014)):
    budget_2014.append(list_2014[i][3])

for j in budget_2014:
    pattern=r'[$][0-9,.]+'
    match = re.findall(pattern, j)
    budget_2014_re.append(match)

revenue_2014=list()
revenue_2014_re=list()
for i in range(len(list_2014)):
    revenue_2014.append(list_2014[i][4])

for j in revenue_2014:
    pattern=r'[$][0-9,.]+'
    match = re.findall(pattern, j)
    revenue_2014_re.append(match)
    
releasedate_2014=list()
for i in range(len(list_2014)):
    releasedate_2014.append(list_2014[i][5])
    
dic_2014={'Movie':name_2014,
          'Release_date':releasedate_2014,
       'Language':lang_2014_re,
       'Runtime':runtime_2014_re,
       'Budget':budget_2014_re,
       'Revenue':revenue_2014_re}

df2014=pd.DataFrame.from_dict(dic_2014)
df2014
# Out:
#                                          Movie        Release_date  \
# 0                      Guardians of the Galaxy     August  1, 2014
# 1                      Guardians of the Galaxy     August  1, 2014
# 2                             Edge of Tomorrow       June  6, 2014
# 3                                 Interstellar    October 26, 2014
# 4                                The Equalizer  September 26, 2014
# 5    The Hobbit: The Battle of the Five Armies   December 17, 2014
# 6                              The Maze Runner  September 19, 2014
# 7                                    John Wick    October 24, 2014
# 8        The Hunger Games: Mockingjay - Part 1   November 21, 2014
# 9                                     Whiplash    January 16, 2014
# 10                          The Imitation Game     August 29, 2014
# 11                                  Big Hero 6    October 25, 2014
# 12                          The Purge: Anarchy       July 18, 2014
# 13     Night at the Museum: Secret of the Tomb   December 19, 2014
# 14              Dawn of the Planet of the Apes       July 11, 2014
# 15                  X-Men: Days of Future Past        May 23, 2014
# 16                                    Sex Tape       July 18, 2014
# 17                                Nightcrawler    October 31, 2014
# 18                                        Fury    October 15, 2014
# 19                                   Gone Girl  September 26, 2014
# 20                Teenage Mutant Ninja Turtles     August  8, 2014
# 21                                     Birdman    October 17, 2014
# 22                                     Birdman    October 17, 2014
# 23                      Penguins of Madagascar   November 26, 2014
# 24                                  Maleficent        May 30, 2014
# 25                                   Annabelle  September 29, 2014
# 26             Transformers: Age of Extinction       June 27, 2014
# 27                          Stonehearst Asylum    October 24, 2014
# 28                              Into the Woods   December  8, 2014
# 29                  How to Train Your Dragon 2       June 13, 2014
# ..                                         ...                 ...
# 600                        Jamie Marks Is Dead    January 19, 2014
# 601                                     Sex Ed   November  7, 2014
# 602                   The Perfect Dictatorship    October 16, 2014
# 603                            Against the Sun   November 22, 2014
# 604                    Un matrimonio da favola      April 10, 2014
# 605                      Decoding Annie Parker      April  4, 2013
# 606                      La mossa del pinguino      March  1, 2014
# 607                                      Messi  September  6, 2014
# 608                                   Red Army    January 23, 2015
# 609         Gett: The Trial of Viviane Amsalem       June 25, 2014
# 610         Gett: The Trial of Viviane Amsalem       June 25, 2014
# 611                                Coming Home    October 10, 2014
# 612                                  Warsaw 44   November 14, 2014
# 613                              Les Souvenirs      March 26, 2014
# 614                               The Humbling    January 23, 2015
# 615                           Time Out of Mind  September  9, 2015
# 616                           Among the Living      March 10, 2014
# 617                                  Northpole   November 15, 2014
# 618                  Kundo: Age of the Rampant       July 23, 2014
# 619                   Jarhead 2: Field of Fire     August 14, 2014
# 620                                    Killers   February  1, 2014
# 621                           Listen Up Philip    January 20, 2014
# 622                                 Not My Day       June 12, 2014
# 623                    The Good Witch's Wonder    October  1, 2014
# 624                                 Effie Gray   December  9, 2014
# 625                                    Savaged      March  6, 2015
# 626                              Lupin the 3rd     August 30, 2014
# 627                                 Jamesy Boy    January  3, 2014
# 628                          Joy of Fatherhood   February  6, 2014
# 629                                Bibi & Tina      March  6, 2014
#
#          Language   Runtime             Budget              Revenue
# 0      [ English]   [2h 1m]  [$170,000,000.00]    [$773,328,629.00]
# 1      [ English]   [2h 1m]  [$170,000,000.00]    [$773,328,629.00]
# 2      [ English]  [1h 53m]  [$178,000,000.00]    [$370,541,256.00]
# 3              []        []                 []                   []
# 4      [ English]  [2h 12m]   [$55,000,000.00]    [$192,330,738.00]
# 5      [ English]  [2h 24m]  [$250,000,000.00]    [$956,019,788.00]
# 6      [ English]  [1h 53m]   [$34,000,000.00]    [$348,300,000.00]
# 7      [ English]  [1h 41m]   [$20,000,000.00]     [$88,761,661.00]
# 8      [ English]   [2h 3m]  [$125,000,000.00]    [$752,100,229.00]
# 9              []        []                 []      [$3,300,000.00]
# 10             []        []                 []     [$14,000,000.00]
# 11             []        []                 []                   []
# 12     [ English]  [1h 44m]    [$9,000,000.00]    [$108,782,847.00]
# 13     [ English]  [1h 37m]  [$127,000,000.00]    [$349,424,282.00]
# 14     [ English]  [2h 10m]  [$170,000,000.00]    [$710,644,566.00]
# 15     [ English]  [2h 11m]  [$250,000,000.00]    [$747,862,775.00]
# 16     [ English]  [1h 37m]   [$40,000,000.00]    [$126,069,509.00]
# 17     [ English]  [1h 58m]    [$8,500,000.00]     [$50,300,000.00]
# 18             []        []                 []     [$68,000,000.00]
# 19             []        []                 []     [$61,000,000.00]
# 20     [ English]  [1h 41m]  [$125,000,000.00]    [$477,200,000.00]
# 21     [ English]   [2h 0m]   [$18,000,000.00]    [$103,215,094.00]
# 22     [ English]   [2h 0m]   [$18,000,000.00]    [$103,215,094.00]
# 23     [ English]  [1h 32m]  [$132,000,000.00]    [$373,552,094.00]
# 24     [ English]  [1h 37m]  [$180,000,000.00]    [$758,539,785.00]
# 25             []        []                 []      [$6,500,000.00]
# 26     [ English]  [2h 45m]  [$210,000,000.00]  [$1,091,405,097.00]
# 27     [ English]  [1h 52m]                 []                   []
# 28             []        []                 []     [$50,000,000.00]
# 29     [ English]  [1h 42m]  [$145,000,000.00]    [$609,123,048.00]
# ..            ...       ...                ...                  ...
# 600            []        []                 []                   []
# 601    [ English]  [1h 30m]                 []                   []
# 602            []        []                 []                   []
# 603    [ English]  [1h 39m]                 []                   []
# 604    [ Italian]        []                 []                   []
# 605            []        []                 []      [$2,000,000.00]
# 606    [ Italian]        []                 []                   []
# 607  [ Castilian]  [1h 33m]                 []                   []
# 608    [ English]  [1h 16m]                 []        [$694,600.00]
# 609            []        []                 []                   []
# 610            []        []                 []                   []
# 611            []        []                 []                   []
# 612            []        []                 []      [$6,700,000.00]
# 613     [ French]  [1h 36m]    [$5,300,000.00]                   []
# 614    [ English]  [1h 52m]    [$2,000,000.00]                   []
# 615    [ English]   [2h 0m]                 []        [$166,775.00]
# 616            []        []                 []                   []
# 617    [ English]        []                 []                   []
# 618            []        []                 []                   []
# 619    [ English]  [1h 43m]                 []                   []
# 620            []        []                 []                   []
# 621            []        []                 []                   []
# 622            []        []                 []                   []
# 623    [ English]  [1h 24m]                 []                   []
# 624    [ English]  [1h 48m]                 []                   []
# 625    [ English]  [1h 31m]                 []                   []
# 626            []        []                 []     [$10,500,000.00]
# 627    [ English]  [1h 49m]                 []                   []
# 628            []        []                 []                   []
# 629            []        []                 []                   []
#
# [630 rows x 6 columns]

# %%
list_2015=money(2015)

name_2015=[]
for i in range(len(list_2015)):
    name_2015.append(list_2015[i][0])
name_2015

language_2015=list()
lang_2015_re=list()
for i in range(len(list_2015)):
    language_2015.append(list_2015[i][1])
    
for j in language_2015:
    pattern=r' \w+$'
    match = re.findall(pattern, j)
    lang_2015_re.append(match)

runtime_2015=list()
runtime_2015_re=list()
for i in range(len(list_2015)):
    runtime_2015.append(list_2015[i][2])

for j in runtime_2015:
    pattern=r'\w+ \w+m$'
    match = re.findall(pattern, j)
    runtime_2015_re.append(match)

budget_2015=list()
budget_2015_re=list()
for i in range(len(list_2015)):
    budget_2015.append(list_2015[i][3])

for j in budget_2015:
    pattern=r'[$][0-9,.]+'
    match = re.findall(pattern, j)
    budget_2015_re.append(match)

revenue_2015=list()
revenue_2015_re=list()
for i in range(len(list_2015)):
    revenue_2015.append(list_2015[i][4])

for j in revenue_2015:
    pattern=r'[$][0-9,.]+'
    match = re.findall(pattern, j)
    revenue_2015_re.append(match)
    
releasedate_2015=list()
for i in range(len(list_2015)):
    releasedate_2015.append(list_2015[i][5])
    
dic_2015={'Movie':name_2015,
          'Release_date':releasedate_2015,
       'Language':lang_2015_re,
       'Runtime':runtime_2015_re,
       'Budget':budget_2015_re,
       'Revenue':revenue_2015_re}

df2015=pd.DataFrame.from_dict(dic_2015)
df2015
# Out:
#                                                  Movie        Release_date  \
# 0                              Avengers: Age of Ultron        May  1, 2015
# 1                              Avengers: Age of Ultron        May  1, 2015
# 2                                              Ant-Man       June 29, 2015
# 3                                          The Martian  September 27, 2015
# 4                             Female War: A Nasty Deal  September 27, 2015
# 5                                   Terminator Genisys       July  1, 2015
# 6                                            Insurgent      March 20, 2015
# 7                                           Inside Out       June  4, 2015
# 8                         Star Wars: The Force Awakens   December 14, 2015
# 9                                   Mad Max: Fury Road        May  7, 2015
# 10                                      Jurassic World       June  9, 2015
# 11                                             Spectre   November  6, 2015
# 12                                               Creed   November 25, 2015
# 13                                          Cinderella      March 13, 2015
# 14                  Mission: Impossible - Rogue Nation       July 31, 2015
# 15                                Fifty Shades of Grey   February 13, 2015
# 16                                            Child 44      April 17, 2015
# 17                                Hotel Transylvania 2  September 25, 2015
# 18                                           Furious 7      April  3, 2015
# 19                        Kingsman: The Secret Service   December 13, 2014
# 20                                        The Revenant   December 16, 2015
# 21                                              Pixels       July 24, 2015
# 22                                              Pixels       July 24, 2015
# 23                                         San Andreas        May 29, 2015
# 24                                             Chappie      March  6, 2015
# 25                                  A Delicious Flight   November  1, 2015
# 26                                    Hitman: Agent 47     August 21, 2015
# 27                                             Sicario  September 14, 2015
# 28               The Hunger Games: Mockingjay - Part 2   November 16, 2015
# 29                                          Goosebumps    October 16, 2015
# ..                                                 ...                 ...
# 600                                           Seashore       June 21, 2015
# 601                                            Re-Kill    October 16, 2015
# 602                                               1944   February 20, 2015
# 603                         Frankenstein vs. The Mummy   February 10, 2015
# 604                                               Riot  September 27, 2015
# 605                                          Evolution  September 14, 2015
# 606                             People, Places, Things     August 14, 2015
# 607                                     Harbinger Down     August  7, 2015
# 608                                     What We Become  September 29, 2015
# 609                                        James White    January 23, 2015
# 610                                        James White    January 23, 2015
# 611                                  Tutte lo vogliono  September 17, 2015
# 612                              3 Türken und ein Baby    January 22, 2015
# 613                                                Tag       July 11, 2015
# 614                                           Abzurdah       June  2, 2015
# 615                                     Avengers Grimm      March 17, 2015
# 616                       The Legend of Barney Thomson      March 11, 2016
# 617                                     The Fear of 13    October 15, 2015
# 618                                           Hellions    January 25, 2015
# 619                                    The Condemned 2   November  6, 2015
# 620                                    Best of Enemies       July 31, 2015
# 621                                            Veteran     August  5, 2015
# 622  LEGO DC Comics Super Heroes: Justice League: A...     August 25, 2015
# 623                               Good Witch Halloween    October 24, 2015
# 624                                         Meadowland      April 17, 2015
# 625                                    A Good American  September 23, 2015
# 626                                        The New Kid   December 23, 2015
# 627                                         13 Cameras     August 30, 2015
# 628                                    Lost in the Sun   November  5, 2015
# 629                                     Scared Topless    October  1, 2015
#
#          Language   Runtime             Budget              Revenue
# 0      [ English]  [2h 21m]  [$280,000,000.00]  [$1,405,403,694.00]
# 1      [ English]  [2h 21m]  [$280,000,000.00]  [$1,405,403,694.00]
# 2              []        []                 []                   []
# 3              []        []                 []                   []
# 4              []        []                 []                   []
# 5      [ English]   [2h 6m]  [$155,000,000.00]    [$440,603,537.00]
# 6      [ English]  [1h 59m]  [$110,000,000.00]    [$295,238,201.00]
# 7              []        []                 []                   []
# 8              []        []                 []                   []
# 9              []        []                 []    [$150,000,000.00]
# 10             []        []                 []    [$150,000,000.00]
# 11             []        []                 []    [$245,000,000.00]
# 12             []        []                 []     [$37,000,000.00]
# 13     [ English]  [1h 45m]   [$95,000,000.00]    [$543,514,353.00]
# 14     [ English]  [2h 11m]  [$150,000,000.00]    [$682,330,139.00]
# 15     [ English]   [2h 5m]   [$40,000,000.00]    [$571,006,128.00]
# 16     [ English]  [2h 17m]   [$50,000,000.00]      [$3,324,330.00]
# 17     [ English]  [1h 29m]   [$80,000,000.00]    [$473,226,958.00]
# 18     [ English]  [2h 17m]  [$190,000,000.00]  [$1,506,249,360.00]
# 19             []        []                 []                   []
# 20             []        []                 []                   []
# 21     [ English]  [1h 45m]   [$88,000,000.00]    [$243,637,091.00]
# 22     [ English]  [1h 45m]   [$88,000,000.00]    [$243,637,091.00]
# 23     [ English]  [1h 54m]  [$110,000,000.00]    [$470,490,832.00]
# 24     [ English]   [2h 0m]   [$49,000,000.00]    [$104,399,548.00]
# 25             []        []                 []                   []
# 26     [ English]  [1h 36m]   [$35,000,000.00]     [$81,967,450.00]
# 27             []        []                 []                   []
# 28             []        []                 []                   []
# 29             []        []                 []     [$58,000,000.00]
# ..            ...       ...                ...                  ...
# 600            []        []                 []                   []
# 601    [ English]  [1h 27m]    [$9,500,000.00]                   []
# 602   [ Estonian]  [1h 40m]    [$2,000,000.00]                   []
# 603    [ English]  [1h 30m]                 []                   []
# 604    [ English]  [1h 28m]                 []                   []
# 605            []        []                 []                   []
# 606    [ English]  [1h 25m]                 []                   []
# 607    [ English]  [1h 22m]                 []                   []
# 608            []        []                 []                   []
# 609    [ English]  [1h 25m]                 []                   []
# 610    [ English]  [1h 25m]                 []                   []
# 611    [ Italian]  [1h 40m]                 []                   []
# 612     [ German]        []                 []                   []
# 613            []        []                 []                   []
# 614  [ Castilian]  [1h 30m]                 []                   []
# 615    [ English]  [1h 30m]                 []                   []
# 616            []        []                 []                   []
# 617    [ English]  [1h 32m]                 []                   []
# 618    [ English]  [1h 20m]                 []                   []
# 619    [ English]  [1h 30m]                 []                   []
# 620    [ English]  [1h 27m]    [$1,000,000.00]                   []
# 621            []        []                 []                   []
# 622    [ English]  [1h 17m]                 []                   []
# 623    [ English]  [1h 24m]                 []                   []
# 624            []        []                 []                   []
# 625    [ English]  [1h 40m]                 []                   []
# 626            []        []                 []                   []
# 627    [ English]  [1h 27m]                 []                   []
# 628    [ English]  [1h 35m]       [$25,000.00]         [$25,000.00]
# 629    [ English]  [1h 20m]                 []                   []
#
# [630 rows x 6 columns]

# %%
list_2016=money(2016)

name_2016=[]
for i in range(len(list_2016)):
    name_2016.append(list_2016[i][0])
name_2016

language_2016=list()
lang_2016_re=list()
for i in range(len(list_2016)):
    language_2016.append(list_2016[i][1])
    
for j in language_2016:
    pattern=r' \w+$'
    match = re.findall(pattern, j)
    lang_2016_re.append(match)

runtime_2016=list()
runtime_2016_re=list()
for i in range(len(list_2016)):
    runtime_2016.append(list_2016[i][2])

for j in runtime_2016:
    pattern=r'\w+ \w+m$'
    match = re.findall(pattern, j)
    runtime_2016_re.append(match)

budget_2016=list()
budget_2016_re=list()
for i in range(len(list_2016)):
    budget_2016.append(list_2016[i][3])

for j in budget_2016:
    pattern=r'[$][0-9,.]+'
    match = re.findall(pattern, j)
    budget_2016_re.append(match)

revenue_2016=list()
revenue_2016_re=list()
for i in range(len(list_2016)):
    revenue_2016.append(list_2016[i][4])

for j in revenue_2016:
    pattern=r'[$][0-9,.]+'
    match = re.findall(pattern, j)
    revenue_2016_re.append(match)
    
releasedate_2016=list()
for i in range(len(list_2016)):
    releasedate_2016.append(list_2016[i][5])
    
dic_2016={'Movie':name_2016,
          'Release_date':releasedate_2016,
       'Language':lang_2016_re,
       'Runtime':runtime_2016_re,
       'Budget':budget_2016_re,
       'Revenue':revenue_2016_re}

df2016=pd.DataFrame.from_dict(dic_2016)
df2016
# Out:
#                                                  Movie        Release_date  \
# 0              Fantastic Beasts and Where to Find Them   November 10, 2016
# 1              Fantastic Beasts and Where to Find Them   November 10, 2016
# 2                           Captain America: Civil War      April 12, 2016
# 3                   Batman v Superman: Dawn of Justice      March 20, 2016
# 4                                     Now You See Me 2       June 10, 2016
# 5                                             Deadpool   February 12, 2016
# 6                                       Doctor Strange   November  4, 2016
# 7                                             Zootopia      March  4, 2016
# 8                                    X-Men: Apocalypse        May 27, 2016
# 9                                              Arrival  September  2, 2016
# 10                                       Hacksaw Ridge   November  4, 2016
# 11                            Kubo and the Two Strings     August 19, 2016
# 12                                          Your Name.       July  3, 2016
# 13                                          La La Land  September  2, 2016
# 14                                      Hidden Figures   December 10, 2016
# 15                          The Huntsman: Winter's War      April 22, 2016
# 16                                           Hart Beat    October 12, 2016
# 17                              Underworld: Blood Wars    January  6, 2017
# 18                                       Suicide Squad     August  1, 2016
# 19                                           Allegiant      March 18, 2016
# 20                                            Bad Moms       July 29, 2016
# 21                        Rogue One: A Star Wars Story   December 10, 2016
# 22                        Rogue One: A Star Wars Story   December 10, 2016
# 23                                                Lion  September 30, 2016
# 24                                             Silence   December 23, 2016
# 25                                       Me Before You       June  3, 2016
# 26                                      The Accountant    October 10, 2016
# 27                                       Sausage Party      March 14, 2016
# 28    Teenage Mutant Ninja Turtles: Out of the Shadows       June  3, 2016
# 29                                           Moonlight  September  2, 2016
# ..                                                 ...                 ...
# 600                                        In Her Name      March 16, 2016
# 601                               Accidentally Engaged    October 30, 2016
# 602  The Rocky Horror Picture Show: Let's Do the Ti...    October 20, 2016
# 603                              Sniper: Ghost Shooter     August  2, 2016
# 604                                              Tower      March 13, 2016
# 605                                        Be Somebody       June 10, 2016
# 606                                               1:54     August 24, 2016
# 607                          The Childhood of a Leader       July 22, 2016
# 608                               The Greasy Strangler    January 22, 2016
# 609                                          Pitchfork  September 23, 2016
# 610                                          Pitchfork  September 23, 2016
# 611                                           Abattoir   December  9, 2016
# 612                                   A December Bride   November 20, 2016
# 613                                         Little Men    January 25, 2016
# 614                                       The Red Pill    October  7, 2016
# 615                                         Our Lovers   February  8, 2016
# 616                                   Roommates Wanted      April 20, 2016
# 617                                  Panfilov's 28 Men   November 24, 2016
# 618                                      Home Invasion   February  2, 2016
# 619                                       Confirmation      April 16, 2016
# 620                                 Quel bravo ragazzo   November 17, 2016
# 621              Batman: Return of the Caped Crusaders    October 11, 2016
# 622                             Special Correspondents      April 22, 2016
# 623                                     Scare Campaign      March 17, 2016
# 624                               The Christmas Dinner   November 24, 2016
# 625                                              Split     August  2, 2016
# 626                                        Arbor Demon   February  3, 2017
# 627                                      Forever Young      March 10, 2016
# 628                                     Daylight's End      April 16, 2016
# 629                Lego Scooby-Doo!: Haunted Hollywood        May  3, 2016
#
#        Language   Runtime             Budget              Revenue
# 0            []        []                 []                   []
# 1            []        []                 []                   []
# 2            []        []                 []                   []
# 3            []        []                 []                   []
# 4    [ English]   [2h 9m]   [$90,000,000.00]    [$334,901,337.00]
# 5            []        []                 []     [$58,000,000.00]
# 6            []        []                 []                   []
# 7    [ English]  [1h 49m]  [$150,000,000.00]  [$1,023,784,195.00]
# 8            []        []                 []                   []
# 9            []        []                 []                   []
# 10           []        []                 []     [$40,000,000.00]
# 11           []        []                 []                   []
# 12           []        []                 []                   []
# 13           []        []                 []                   []
# 14           []        []                 []                   []
# 15   [ English]  [1h 54m]  [$115,000,000.00]    [$164,602,163.00]
# 16   [ Flemish]  [1h 26m]                 []                   []
# 17           []        []                 []     [$35,000,000.00]
# 18           []        []                 []                   []
# 19           []        []                 []    [$110,000,000.00]
# 20   [ English]  [1h 40m]   [$20,000,000.00]    [$183,936,074.00]
# 21           []        []                 []                   []
# 22           []        []                 []                   []
# 23           []        []                 []                   []
# 24           []        []                 []                   []
# 25   [ English]  [1h 50m]   [$20,000,000.00]    [$207,945,075.00]
# 26           []        []                 []                   []
# 27           []        []                 []                   []
# 28   [ English]  [1h 52m]  [$135,000,000.00]    [$245,623,848.00]
# 29           []        []                 []                   []
# ..          ...       ...                ...                  ...
# 600          []        []                 []                   []
# 601  [ English]  [1h 26m]                 []                   []
# 602  [ English]  [1h 28m]                 []                   []
# 603  [ English]  [1h 40m]    [$3,000,000.00]                   []
# 604          []        []                 []                   []
# 605  [ English]  [1h 28m]                 []                   []
# 606   [ French]  [1h 46m]                 []                   []
# 607  [ English]  [1h 55m]    [$3,000,000.00]                   []
# 608          []        []                 []                   []
# 609  [ English]  [1h 34m]                 []                   []
# 610  [ English]  [1h 34m]                 []                   []
# 611          []        []                 []                   []
# 612  [ English]   [2h 0m]                 []                   []
# 613          []        []                 []                   []
# 614          []        []                 []                   []
# 615          []        []                 []      [$1,400,000.00]
# 616          []        []                 []                   []
# 617          []        []                 []                   []
# 618  [ English]  [1h 28m]                 []                   []
# 619  [ English]  [1h 50m]                 []                   []
# 620  [ Italian]        []                 []                   []
# 621          []        []                 []      [$3,500,000.00]
# 622          []        []                 []                   []
# 623  [ English]  [1h 16m]                 []                   []
# 624          []        []                 []                   []
# 625  [ English]  [1h 30m]                 []                   []
# 626  [ English]  [1h 40m]                 []                   []
# 627  [ English]  [1h 35m]                 []                   []
# 628  [ English]   [2h 0m]    [$2,000,000.00]                   []
# 629  [ English]  [1h 15m]                 []                   []
#
# [630 rows x 6 columns]

# %%
list_2017=money(2017)

name_2017=[]
for i in range(len(list_2017)):
    name_2017.append(list_2017[i][0])
name_2017

language_2017=list()
lang_2017_re=list()
for i in range(len(list_2017)):
    language_2017.append(list_2017[i][1])
    
for j in language_2017:
    pattern=r' \w+$'
    match = re.findall(pattern, j)
    lang_2017_re.append(match)

runtime_2017=list()
runtime_2017_re=list()
for i in range(len(list_2017)):
    runtime_2017.append(list_2017[i][2])

for j in runtime_2017:
    pattern=r'\w+ \w+m$'
    match = re.findall(pattern, j)
    runtime_2017_re.append(match)

budget_2017=list()
budget_2017_re=list()
for i in range(len(list_2017)):
    budget_2017.append(list_2017[i][3])

for j in budget_2017:
    pattern=r'[$][0-9,.]+'
    match = re.findall(pattern, j)
    budget_2017_re.append(match)

revenue_2017=list()
revenue_2017_re=list()
for i in range(len(list_2017)):
    revenue_2017.append(list_2017[i][4])

for j in revenue_2017:
    pattern=r'[$][0-9,.]+'
    match = re.findall(pattern, j)
    revenue_2017_re.append(match)
    
releasedate_2017=list()
for i in range(len(list_2017)):
    releasedate_2017.append(list_2017[i][5])
    
dic_2017={'Movie':name_2017,
          'Release_date':releasedate_2017,
       'Language':lang_2017_re,
       'Runtime':runtime_2017_re,
       'Budget':budget_2017_re,
       'Revenue':revenue_2017_re}

df2017=pd.DataFrame.from_dict(dic_2017)
df2017
# Out:
#                                                  Movie        Release_date  \
# 0                                      A Dog's Purpose    January 27, 2017
# 1                                      A Dog's Purpose    January 27, 2017
# 2                                       Justice League   November 13, 2017
# 3                                       Thor: Ragnarok    October 10, 2017
# 4                             Star Wars: The Last Jedi   December  9, 2017
# 5                                                 Coco   November 22, 2017
# 6                                    Blade Runner 2049    October  3, 2017
# 7                                 The Greatest Showman   December  8, 2017
# 8                       Guardians of the Galaxy Vol. 2        May  5, 2017
# 9                                                Split  September 26, 2016
# 10                                               Logan      March  3, 2017
# 11                                        Wonder Woman        May 25, 2017
# 12                           Christmas Wedding Planner   December 14, 2017
# 13                                             Dunkirk       July 19, 2017
# 14                              Spider-Man: Homecoming       July  7, 2017
# 15                                            The Post   December 22, 2017
# 16    Pirates of the Caribbean: Dead Men Tell No Tales        May 26, 2017
# 17                                            Geostorm    October 20, 2017
# 18                                Beauty and the Beast      March  2, 2017
# 19                                  The Shape of Water  September  2, 2017
# 20                                     Alien: Covenant        May 19, 2017
# 21                                        Molly's Game    October 11, 2017
# 22                                        Molly's Game    October 11, 2017
# 23                                              Wonder   November 17, 2017
# 24                             The Fate of the Furious      April 14, 2017
# 25                                  Kong: Skull Island      March 10, 2017
# 26                                              Cars 3        May 23, 2017
# 27                                            Baywatch        May 26, 2017
# 28                                 Annabelle: Creation       June 19, 2017
# 29                                             Revenge    January 19, 2018
# ..                                                 ...                 ...
# 600                                       Walk with Me      March 12, 2017
# 601                                    Promise at Dawn   December 20, 2017
# 602                                  The Shadow Effect        May  2, 2017
# 603                         Katherine Ryan: In Trouble   February 14, 2017
# 604                                    Naples in Veils      April 20, 2018
# 605                                   Ajin: Demi-Human      March 13, 2018
# 606                                          Wakefield  September  2, 2016
# 607  Michael Bolton's Big, Sexy Valentine's Day Spe...   February  7, 2017
# 608                         The Houses October Built 2  September 22, 2017
# 609                             BPM (Beats per Minute)        May 20, 2017
# 610                             BPM (Beats per Minute)        May 20, 2017
# 611                               Awaken the Shadowman       July 21, 2017
# 612                      Literally, Right Before Aaron      April 22, 2017
# 613                                    15+ IQ Krachoot     August  3, 2017
# 614                                   A Sort of Family  September  8, 2017
# 615                                        Ghost House     August 25, 2017
# 616                    Comment j'ai rencontré mon père       June  7, 2017
# 617                             Racer and the Jailbird    October 21, 2017
# 618                                      The Exception       June  2, 2017
# 619                                         The Dinner        May  5, 2017
# 620                              R.A.I.D. Special Unit   December 19, 2016
# 621                                              78/52    January 23, 2017
# 622                                           Patients      March  1, 2017
# 623                                     With Open Arms      April  5, 2017
# 624                                     Beyond Skyline   December 15, 2017
# 625                                  The Good Catholic  September  8, 2017
# 626                                   The Female Brain       June 17, 2017
# 627                                       Happy Family   February  9, 2018
# 628                                      Kiss and Kill     August  8, 2017
# 629                                 Bigger Fatter Liar      April 18, 2017
#
#        Language   Runtime            Budget            Revenue
# 0            []        []                []   [$22,000,000.00]
# 1            []        []                []   [$22,000,000.00]
# 2            []        []                []                 []
# 3            []        []                []                 []
# 4            []        []                []                 []
# 5            []        []                []  [$175,000,000.00]
# 6            []        []                []                 []
# 7            []        []                []                 []
# 8            []        []                []                 []
# 9            []        []                []                 []
# 10           []        []                []                 []
# 11           []        []                []                 []
# 12   [ English]  [1h 26m]                []                 []
# 13           []        []                []                 []
# 14           []        []                []  [$175,000,000.00]
# 15           []        []                []                 []
# 16           []        []                []                 []
# 17           []        []                []  [$120,000,000.00]
# 18           []        []                []                 []
# 19           []        []                []                 []
# 20           []        []                []   [$97,000,000.00]
# 21           []        []                []                 []
# 22           []        []                []                 []
# 23           []        []                []                 []
# 24           []        []                []                 []
# 25           []        []                []  [$185,000,000.00]
# 26           []        []                []                 []
# 27   [ English]  [1h 56m]  [$69,000,000.00]  [$177,856,751.00]
# 28           []        []                []                 []
# 29           []        []                []    [$2,900,000.00]
# ..          ...       ...               ...                ...
# 600  [ English]  [1h 34m]                []                 []
# 601          []        []                []                 []
# 602  [ English]  [1h 33m]   [$9,000,000.00]                 []
# 603  [ English]   [1h 3m]                []                 []
# 604          []        []                []                 []
# 605          []        []                []                 []
# 606          []        []                []                 []
# 607  [ English]  [0h 54m]                []                 []
# 608  [ English]  [1h 39m]                []                 []
# 609          []        []                []    [$6,600,000.00]
# 610          []        []                []    [$6,600,000.00]
# 611  [ English]  [1h 30m]                []                 []
# 612  [ English]  [1h 37m]                []                 []
# 613          []        []                []                 []
# 614          []        []                []                 []
# 615  [ English]  [1h 32m]                []                 []
# 616   [ French]  [1h 22m]                []                 []
# 617          []        []                []                 []
# 618          []        []                []                 []
# 619  [ English]   [2h 0m]                []    [$1,323,312.00]
# 620          []        []                []           [$32.00]
# 621          []        []                []                 []
# 622   [ French]  [1h 50m]                []                 []
# 623          []        []                []                 []
# 624  [ English]  [1h 45m]  [$20,000,000.00]      [$992,181.00]
# 625  [ English]  [1h 36m]                []                 []
# 626  [ English]  [1h 38m]                []                 []
# 627  [ English]  [1h 33m]                []   [$26,441,892.00]
# 628  [ English]  [1h 21m]                []                 []
# 629          []        []                []    [$1,000,000.00]
#
# [630 rows x 6 columns]
